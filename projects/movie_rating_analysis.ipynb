# %% [markdown]
# <a href="https://colab.research.google.com/github/juwon-ds/practice-data-analysis/blob/main/projects/movie_rating_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    'movie': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],
    'genre': ['Action', 'Drama', 'Action', 'Comedy', 'Drama', 'Comedy', 'Action', 'Drama', 'Comedy', 'Action'],
    'rating': [8.5, 7.2, 9.0, 6.5, 8.0, 7.0, 8.8, 7.5, 6.8, 9.2],
    'runtime': [120, 150, 110, 90, 140, 100, 130, 145, 95, 125]
}

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#   movie   genre  rating  runtime
# 0     A  Action     8.5      120
# 1     B   Drama     7.2      150
# 2     C  Action     9.0      110
# 3     D  Comedy     6.5       90
# 4     E   Drama     8.0      140

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movie    10 non-null     object
#  1   genre    10 non-null     object
#  2   rating   10 non-null     float64
#  3   runtime  10 non-null     int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 452.0+ bytes

# %%
df.isnull().sum()
# Out:
# movie      0
# genre      0
# rating     0
# runtime    0
# dtype: int64

# %% [markdown]
# Question
#
# *   Is there a difference in rating by genre?
# *   Is there a relationship between runtime and rating?

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,4))

plt.subplot(1,3,1)
df.groupby('genre')['rating'].mean().plot(kind='bar')
plt.xlabel('Genre')
plt.ylabel('Rating')
plt.title('Average Rating by Genre')

plt.subplot(1,3,2)
plt.scatter(df['runtime'], df['rating'])
plt.xlabel('Runtime')
plt.ylabel('Rating')
plt.title('Runtime vs Rating')

plt.subplot(1,3,3)
df['rating'].plot(kind='hist')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of rating')

plt.tight_layout()
plt.show()

# %% [markdown]
# Conclusion
#
# *   Genre of action high in average rating.
# *   There is no clear relationship between runtime and rating.
# *   Rating distribute more between 7 and 9.
